# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt

sys.path.append("helpers")
from helpers import LORIS_data_preparation
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# LORIS saved query (all data)
full = pd.read_csv("../../diagnosis_predictor/data/raw/LORIS-release-10.csv", dtype=object)

# %%
df = LORIS_data_preparation.prepare_data(full)
# Out:
# /Users/home/Repos/hbn/HBN-scripts/exploration/helpers/LORIS_data_preparation.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full["ID"] = full_for_EID_check.iloc[:, 0]

# %%
for i, col in enumerate(df.columns):
    if "PreInt" in col:
        print(col)
        print(df[col].value_counts())
# Out:
# PreInt_Demos_Fam,Child_CountryOrigin
# USA                                          2821
# United States                                 474
# United Kingdom                                 12
# Guatemala                                       9
# Ethiopia                                        8
# China                                           7
# Russia                                          7
# Puerto Rico                                     6
# India                                           5
# Israel                                          5
# usa                                             5
# Dominican Republic                              4
# France                                          4
# South Korea                                     4
# US                                              3
# Canada                                          3
# Bulgaria                                        3
# Germany                                         3
# ...

# %%
age = "Basic_Demos,Age"
sex = "Basic_Demos,Sex"
spelling = "WIAT,WIAT_Spell_Stnd"

df[age] = np.floor(df[age].astype(float))

print(len(df[~(df[spelling].isnull())][spelling]))
print("6yo with WIAT: ", len(df[(df[age] == 6) & ~(df[spelling].isnull())][spelling]))
print("5yo with WIAT: ", len(df[(df[age] == 5) & ~(df[spelling].isnull())][spelling]))
print("5 and 6yo with WIAT: ", len(df[((df[age] == 5) | (df[age] == 6)) & ~(df[spelling].isnull())]))

all_wiat_cols = [x for x in df.columns if "WIAT" in x]
all_wisc_cols = [x for x in df.columns if "WISC" in x]
five_and_six_wiat = df[((df[age] == 5) | (df[age] == 6)) & ~(df[spelling].isnull())]
five_and_six_wiat[all_wiat_cols + all_wisc_cols + [age, sex]].to_csv("five_and_six_wiat.csv")
# Out:
# 3682
# 6yo with WIAT:  386
# 5yo with WIAT:  249
# 5 and 6yo with WIAT:  635

# %%
print("Have FamHx filled:", len(five_and_six_wiat[five_and_six_wiat["PreInt_FamHx,﻿EID"].notna()]))
print("Parent learning problems:", len(five_and_six_wiat[five_and_six_wiat["PreInt_FamHx,f_learn"] == "1"]))
print("\nHave FamHx_RDC filled:", len(five_and_six_wiat[five_and_six_wiat["PreInt_FamHx_RDC,EID"].notna()]))

fam_diag_cols = [x for x in five_and_six_wiat.columns if "dx" in x and "dt" not in x and "sev" not in x]
for diag in fam_diag_cols:
    display(five_and_six_wiat[diag].value_counts())
# Out:
# Have FamHx filled: 37
# Parent learning problems: 3
#
# Have FamHx_RDC filled: 595
# No Diagnosis                 53
# Genarlized Anxiety           11
# Major Depressive Disorder    10
# ADHD                          5
# Alcohol                       3
# Polysubstance                 2
# No Response                   2
# Other Diagnosis               2
# Adjustment Disorder           1
# OCD                           1
# Other Anxiety                 1
# Name: PreInt_FamHx_RDC,fcodxm_1, dtype: int64
# No Diagnosis                 54
# No Response                   2
# Genarlized Anxiety            2
# Bipolar II                    1
# Major Depressive Disorder     1
# Name: PreInt_FamHx_RDC,fcodxm_2, dtype: int64
# No Diagnosis    53
# No Response      3
# Name: PreInt_FamHx_RDC,fcodxm_3, dtype: int64
# No Diagnosis                    445
# ADHD                             29
# Major Depressive Disorder        21
# Other Diagnosis                  17
# ...

# %%
relevant_assessments_read = ["PreInt_FamHx", "PreInt_EduHx", "PSI", "RBS", "APQ_P", "CBCL", "SDQ", "PreInt_DevHx", "ESWAN", "NIH_Scores"]
display(LORIS_data_preparation.get_cumul_df(five_and_six_wiat, relevant_assessments_read))
# Out:
#    Respondents                                        Assessments  \
# 0          635                                     [PreInt_EduHx]
# 1          634                       [PreInt_EduHx, PreInt_DevHx]
# 2          630           [PreInt_EduHx, PreInt_DevHx, NIH_Scores]
# 3          625      [PreInt_EduHx, PreInt_DevHx, NIH_Scores, SDQ]
# 4          547  [PreInt_EduHx, PreInt_DevHx, NIH_Scores, SDQ, ...
# 5          508  [PreInt_EduHx, PreInt_DevHx, NIH_Scores, SDQ, ...
# 6          475  [PreInt_EduHx, PreInt_DevHx, NIH_Scores, SDQ, ...
# 7          434  [PreInt_EduHx, PreInt_DevHx, NIH_Scores, SDQ, ...
# 8          360  [PreInt_EduHx, PreInt_DevHx, NIH_Scores, SDQ, ...
#
#    N of Assessments Last Assessment
# 0                 1    PreInt_EduHx
# 1                 2    PreInt_DevHx
# 2                 3      NIH_Scores
# 3                 4             SDQ
# 4                 5             PSI
# 5                 6           ESWAN
# 6                 7           APQ_P
# ...

# %%
five_and_six_wiat_sdq = LORIS_data_preparation.get_data_up_to_assessment(five_and_six_wiat, "PSI", relevant_assessments_read)

print(five_and_six_wiat["PreInt_DevHx,skill_age_15"].isna().sum())
print(len(five_and_six_wiat[~(five_and_six_wiat["PreInt_DevHx,skill_age_15"].isna()) | ~(five_and_six_wiat["PreInt_DevHx,skill_age_15"].isna())]))
# Out:
# 272
# 363

# %%
five_and_six_wiat_sdq["PreInt_DevHx,skill_range_15"].value_counts()
# Out:
# Normal    135
# Late       90
# Early      47
# normal      8
# late        7
# early       2
# early       2
# DK          1
# momdad      1
# Early       1
# 2 yrs       1
# Name: PreInt_DevHx,skill_range_15, dtype: int64
