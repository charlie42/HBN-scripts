# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt

sys.path.append("helpers")
from helpers import LORIS_data_preparation

# %%
# LORIS saved query (all data)
full = pd.read_csv("../../diagnosis_predictor/data/raw/LORIS-release-10.csv", dtype=object)

# %%
df = LORIS_data_preparation.prepare_data(full)
# Out:
# /Users/home/Repos/hbn/HBN-scripts/exploration/helpers/LORIS_data_preparation.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full["ID"] = full_for_EID_check.iloc[:, 0]

# %%
age = "Basic_Demos,Age"
sex = "Basic_Demos,Sex"
spelling = "WIAT,WIAT_Spell_Stnd"

df[age] = np.floor(df[age].astype(float))

print(len(df[~(df[spelling].isnull())][spelling]))
print("6yo with WIAT: ", len(df[(df[age] == 6) & ~(df[spelling].isnull())][spelling]))
print("5yo with WIAT: ", len(df[(df[age] == 5) & ~(df[spelling].isnull())][spelling]))
print("5 and 6yo with WIAT: ", len(df[((df[age] == 5) | (df[age] == 6)) & ~(df[spelling].isnull())]))

all_wiat_cols = [x for x in df.columns if "WIAT" in x]
all_wisc_cols = [x for x in df.columns if "WISC" in x]
five_and_six_wiat = df[((df[age] == 5) | (df[age] == 6)) & ~(df[spelling].isnull())]
five_and_six_wiat[all_wiat_cols + all_wisc_cols + [age, sex]].to_csv("five_and_six_wiat.csv")
# Out:
# 3682
# 6yo with WIAT:  386
# 5yo with WIAT:  249
# 5 and 6yo with WIAT:  635

# %%
print("Has Parent learning problems filled:", len(five_and_six_wiat[five_and_six_wiat["PreInt_FamHx,f_learn"].notna()]))
print("Has Spoke first word age filled:", len(five_and_six_wiat[five_and_six_wiat["PreInt_DevHx,skill_age_15"].notna() | five_and_six_wiat["PreInt_DevHx,skill_range_15"].notna()]))
print("Has Named objects age filled:", len(five_and_six_wiat[five_and_six_wiat["PreInt_DevHx,skill_age_16"].notna() | five_and_six_wiat["PreInt_DevHx,skill_range_16"].notna()]))
print("Has Put 2 or 3 words together age filled:", len(five_and_six_wiat[five_and_six_wiat["PreInt_DevHx,skill_age_17"].notna() | five_and_six_wiat["PreInt_DevHx,skill_range_17"].notna()]))
print("Has Support filled:", len(five_and_six_wiat[five_and_six_wiat["PreInt_EduHx,CPSE"].notna() | five_and_six_wiat["PreInt_EduHx,EI"].notna()]))
print("Has Prematurity filled:", len(five_and_six_wiat[five_and_six_wiat["PreInt_DevHx,premature"].notna() | five_and_six_wiat["PreInt_DevHx,premature"].notna()]))


print("\nHas CBCL filled:", len(five_and_six_wiat[five_and_six_wiat["CBCL,EID"].notna()]))
print("Has CBCL-Pre filled:", len(five_and_six_wiat[five_and_six_wiat["CBCL_Pre,EID"].notna()]))
# Out:
# Has Parent learning problems filled: 37
# Has Spoke first word age filled: 562
# Has Named objects age filled: 427
# Has Put 2 or 3 words together age filled: 507
# Has Support filled: 628
# Has Prematurity filled: 552
#
# Has CBCL filled: 487
# Has CBCL-Pre filled: 147

# %%
# Correlation and multiple regression

lang_cols = ["PreInt_Lang,Child_Lang1_Life",
                "PreInt_Lang,Child_Lang2_Life",
                "PreInt_Lang,Child_Lang3_Life"]    
five_and_six_wiat[lang_cols] = five_and_six_wiat[lang_cols].apply(pd.to_numeric)
five_and_six_wiat["PreInt_Lang,NumLangs"] = five_and_six_wiat[lang_cols].sum(axis=1)

for_corr = five_and_six_wiat[["PreInt_FamHx,f_learn",
                "PreInt_DevHx,skill_age_15",
                "PreInt_DevHx,skill_range_15",
                "PreInt_DevHx,skill_age_16",
                "PreInt_DevHx,skill_range_16",
                "PreInt_DevHx,skill_age_17",
                "PreInt_DevHx,skill_range_17",
                 "PreInt_EduHx,CPSE",
                 "PreInt_EduHx,EI",
                 "PreInt_DevHx,premature",
                 "PreInt_Lang,NumLangs",
                 spelling,
                ]]

# Transform PreInt_DevHx,skill_range_X cols into a number (Early or early=-1, Normal or normal=0, Late or late=1, other=NaN)
cols = [x for x in for_corr.columns if "PreInt_DevHx,skill_range_" in x]   
dict = {"Early": -1, "early": -1, "Normal": 0, "normal": 0, "Late": 1, "late": 1}  
for_corr = LORIS_data_preparation.replace_with_dict_otherwise_nan(for_corr, cols, dict)

for col in for_corr.columns:
    for_corr[col] = for_corr[col].astype(float)

for col in for_corr.columns:
    if col != spelling:
        df = for_corr[[col, spelling]].dropna()
        print(df.corr())
        if "age" in col:
            df.plot(col, spelling, kind="scatter")
        else:
            df.boxplot(spelling, col)
        plt.show()
# Out:
#                       PreInt_FamHx,f_learn  WIAT,WIAT_Spell_Stnd
# PreInt_FamHx,f_learn              1.000000             -0.061014
# WIAT,WIAT_Spell_Stnd             -0.061014              1.000000
# /Users/home/Repos/hbn/HBN-scripts/exploration/helpers/LORIS_data_preparation.py:250: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = data[col].astype(str).replace(dict)
# /var/folders/63/96f7chcx7qq5r9fq4x0x72bw0000gq/T/ipykernel_46811/2151813775.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for_corr[col] = for_corr[col].astype(float)
#                            PreInt_DevHx,skill_age_15  WIAT,WIAT_Spell_Stnd
# PreInt_DevHx,skill_age_15                   1.000000             -0.144039
# WIAT,WIAT_Spell_Stnd                       -0.144039              1.000000
#                              PreInt_DevHx,skill_range_15  WIAT,WIAT_Spell_Stnd
# PreInt_DevHx,skill_range_15                     1.000000             -0.246855
# WIAT,WIAT_Spell_Stnd                           -0.246855              1.000000
#                            PreInt_DevHx,skill_age_16  WIAT,WIAT_Spell_Stnd
# PreInt_DevHx,skill_age_16                   1.000000             -0.225388
# WIAT,WIAT_Spell_Stnd                       -0.225388              1.000000
#                              PreInt_DevHx,skill_range_16  WIAT,WIAT_Spell_Stnd
# PreInt_DevHx,skill_range_16                     1.000000             -0.245527
# WIAT,WIAT_Spell_Stnd                           -0.245527              1.000000
#                            PreInt_DevHx,skill_age_17  WIAT,WIAT_Spell_Stnd
# PreInt_DevHx,skill_age_17                   1.000000             -0.212111
# WIAT,WIAT_Spell_Stnd                       -0.212111              1.000000
#                              PreInt_DevHx,skill_range_17  WIAT,WIAT_Spell_Stnd
# PreInt_DevHx,skill_range_17                     1.000000             -0.228909
# WIAT,WIAT_Spell_Stnd                           -0.228909              1.000000
#                       PreInt_EduHx,CPSE  WIAT,WIAT_Spell_Stnd
# PreInt_EduHx,CPSE              1.000000             -0.107569
# WIAT,WIAT_Spell_Stnd          -0.107569              1.000000
#                       PreInt_EduHx,EI  WIAT,WIAT_Spell_Stnd
# PreInt_EduHx,EI              1.000000             -0.114304
# WIAT,WIAT_Spell_Stnd        -0.114304              1.000000
#                         PreInt_DevHx,premature  WIAT,WIAT_Spell_Stnd
# PreInt_DevHx,premature                1.000000             -0.063694
# WIAT,WIAT_Spell_Stnd                 -0.063694              1.000000
#                       PreInt_Lang,NumLangs  WIAT,WIAT_Spell_Stnd
# PreInt_Lang,NumLangs              1.000000              0.041409
# WIAT,WIAT_Spell_Stnd              0.041409              1.000000

# %%
for_lr = for_corr[["PreInt_DevHx,skill_range_15",
                   "PreInt_DevHx,skill_range_16",
                   "PreInt_DevHx,skill_range_17",
                   "PreInt_EduHx,CPSE",
                   "PreInt_EduHx,EI",
                   "PreInt_DevHx,premature",
                   "PreInt_Lang,NumLangs",
                   spelling
                  ]]
for_lr = for_lr.dropna()
x_cols = [x for x in for_lr.columns if x != spelling]

from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.linear_model import ElasticNet, Lasso
from sklearn.metrics import mean_absolute_error, r2_score

train, test = train_test_split(for_lr)
X_train, y_train = train[x_cols], train[spelling]
X_test, y_test = test[x_cols], test[spelling]
print(X_train.shape, y_train.shape)

en = ElasticNet()
cv = StratifiedKFold(5)
cv_results = cross_validate(en, X_train, y_train, cv=cv, return_estimator=True)
print("r2: ", cv_results['test_score'].mean(), cv_results['test_score'])

for model in cv_results['estimator']:
    coefs = pd.DataFrame(zip(model.coef_, x_cols), columns = ["Coefficient", "Item"])
    display(coefs)
# Out:
# (162, 7) (162,)
# r2:  0.042150505663881344 [ 0.04613446  0.04826483 -0.00938967  0.06227149  0.06347141]
# /Users/home/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
#    Coefficient                         Item
# 0    -1.869176  PreInt_DevHx,skill_range_15
# 1    -0.523466  PreInt_DevHx,skill_range_16
# 2    -1.331577  PreInt_DevHx,skill_range_17
# 3    -1.354470            PreInt_EduHx,CPSE
# 4     0.000000              PreInt_EduHx,EI
# 5    -0.000000       PreInt_DevHx,premature
# 6    -0.693349         PreInt_Lang,NumLangs
#    Coefficient                         Item
# 0    -1.794479  PreInt_DevHx,skill_range_15
# 1    -0.713892  PreInt_DevHx,skill_range_16
# 2    -0.675620  PreInt_DevHx,skill_range_17
# 3    -1.439767            PreInt_EduHx,CPSE
# 4    -0.000000              PreInt_EduHx,EI
# 5    -0.000000       PreInt_DevHx,premature
# 6     0.437656         PreInt_Lang,NumLangs
#    Coefficient                         Item
# 0    -1.646726  PreInt_DevHx,skill_range_15
# 1    -1.242457  PreInt_DevHx,skill_range_16
# 2    -1.620204  PreInt_DevHx,skill_range_17
# 3    -1.292174            PreInt_EduHx,CPSE
# 4     0.000000              PreInt_EduHx,EI
# 5    -0.000000       PreInt_DevHx,premature
# 6    -0.971345         PreInt_Lang,NumLangs
#    Coefficient                         Item
# 0    -1.927596  PreInt_DevHx,skill_range_15
# 1    -0.778259  PreInt_DevHx,skill_range_16
# 2    -1.120323  PreInt_DevHx,skill_range_17
# 3    -0.934650            PreInt_EduHx,CPSE
# 4     0.000000              PreInt_EduHx,EI
# 5     0.000000       PreInt_DevHx,premature
# 6    -0.057084         PreInt_Lang,NumLangs
#    Coefficient                         Item
# 0    -1.732258  PreInt_DevHx,skill_range_15
# 1    -1.038288  PreInt_DevHx,skill_range_16
# 2    -1.110832  PreInt_DevHx,skill_range_17
# 3    -1.092500            PreInt_EduHx,CPSE
# 4     0.000000              PreInt_EduHx,EI
# 5     0.000000       PreInt_DevHx,premature
# 6    -0.103059         PreInt_Lang,NumLangs

# %%
# Check for corr between each other
cols = [x for x in for_corr.columns if "age" in x]
for_self_corr = for_corr[cols].dropna()
display(for_self_corr.corr())

cols = [x for x in for_corr.columns if "range" in x]
for_self_corr = for_corr[cols].dropna()
display(for_self_corr.corr())
# Out:
#                            PreInt_DevHx,skill_age_15  \
# PreInt_DevHx,skill_age_15                   1.000000
# PreInt_DevHx,skill_age_16                   0.613768
# PreInt_DevHx,skill_age_17                   0.505055
#
#                            PreInt_DevHx,skill_age_16  \
# PreInt_DevHx,skill_age_15                   0.613768
# PreInt_DevHx,skill_age_16                   1.000000
# PreInt_DevHx,skill_age_17                   0.790566
#
#                            PreInt_DevHx,skill_age_17
# PreInt_DevHx,skill_age_15                   0.505055
# PreInt_DevHx,skill_age_16                   0.790566
# PreInt_DevHx,skill_age_17                   1.000000
#                              PreInt_DevHx,skill_range_15  \
# PreInt_DevHx,skill_range_15                     1.000000
# PreInt_DevHx,skill_range_16                     0.891071
# PreInt_DevHx,skill_range_17                     0.810453
#
#                              PreInt_DevHx,skill_range_16  \
# PreInt_DevHx,skill_range_15                     0.891071
# PreInt_DevHx,skill_range_16                     1.000000
# PreInt_DevHx,skill_range_17                     0.870903
#
#                              PreInt_DevHx,skill_range_17
# PreInt_DevHx,skill_range_15                     0.810453
# PreInt_DevHx,skill_range_16                     0.870903
# PreInt_DevHx,skill_range_17                     1.000000

# %%
relevant_assessments_read = ["WISC", "PreInt_EduHx", "PreInt_DevHx", "PreInt_TxHx", "PreInt_Lang", "PreInt_FamHx", "PreInt_FamHx_RDC", 
                             "PreInt_Demos_Home", "PreInt_Demos_Fam", "NIH_Scores", "SympChck", "SCQ", "Barratt", 
        "ASSQ", "ARI_P", "SDQ", "SWAN", "SRS", "CBCL", "ICU_P", "ICU_SR", "PANAS", "APQ_P", "PCIAT", "DTS", "ESWAN", "MFQ_P", "APQ_SR", 
        "WHODAS_P", "CIS_P", "SAS", "PSI", "RBS", "PhenX_Neighborhood", "WHODAS_SR", "CIS_SR", "SCARED_P", "SCARED_SR", 
        "C3SR", "CCSC", "CPIC", "YSR", "PhenX_SchoolRisk", "CBCL_Pre", "SRS_Pre", "ASR"]
display(LORIS_data_preparation.get_cumul_df(five_and_six_wiat, relevant_assessments_read))
# Out:
#     Respondents                                        Assessments  Min Age  \
# 0           635                                     [PreInt_EduHx]      5.0
# 1           634                        [PreInt_EduHx, PreInt_TxHx]      5.0
# 2           633          [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx]      5.0
# 3           630  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 4           627  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 5           626  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 6           624  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 7           619  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 8           613  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 9           613  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 10          607  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 11          605  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 12          571  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 13          571  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 14          570  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 15          568  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 16          526  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 17          500  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 18          479  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 19          478  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 20          466  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 21          466  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 22          466  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 23          438  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 24          363  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 25          347  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 26          346  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 27          346  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 28          312  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 29          312  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 30          312  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 31          290  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 32          289  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 33          249  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      5.0
# 34            0  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      NaN
# 35            0  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      NaN
# 36            0  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      NaN
# 37            0  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      NaN
# 38            0  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      NaN
# 39            0  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      NaN
# 40            0  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      NaN
# 41            0  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      NaN
# 42            0  [PreInt_EduHx, PreInt_TxHx, PreInt_DevHx, Symp...      NaN
#
#     N of Assessments     Last Assessment
# 0                  1        PreInt_EduHx
# 1                  2         PreInt_TxHx
# 2                  3        PreInt_DevHx
# 3                  4            SympChck
# 4                  5          NIH_Scores
# 5                  6                 SCQ
# 6                  7                 SDQ
# 7                  8             Barratt
# 8                  9    PreInt_Demos_Fam
# 9                 10   PreInt_Demos_Home
# 10                11                ASSQ
# 11                12               ARI_P
# 12                13    PreInt_FamHx_RDC
# 13                14               ICU_P
# 14                15                 DTS
# 15                16               PCIAT
# 16                17                SWAN
# 17                18                 PSI
# 18                19            WHODAS_P
# 19                20                 SAS
# 20                21         PreInt_Lang
# 21                22               ESWAN
# 22                23               CIS_P
# 23                24               APQ_P
# 24                25                 SRS
# 25                26                 RBS
# 26                27  PhenX_Neighborhood
# 27                28                CBCL
# 28                29                WISC
# 29                30               MFQ_P
# 30                31            SCARED_P
# 31                32              CIS_SR
# 32                33           WHODAS_SR
# 33                34              APQ_SR
# 34                35            CBCL_Pre
# 35                36             SRS_Pre
# 36                37           SCARED_SR
# 37                38    PhenX_SchoolRisk
# 38                39                 ASR
# 39                40                C3SR
# 40                41                CCSC
# 41                42                CPIC
# 42                43                 YSR
